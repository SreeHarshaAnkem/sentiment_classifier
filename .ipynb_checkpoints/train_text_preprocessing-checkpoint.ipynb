# %%
import re
import os

import numpy as np
import pandas as pd

from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

from multiprocessing import Pool

from collections import Counter
from itertools import chain

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from jupyterthemes import jtplot
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4788d77f8d31> in <module>()
#      17 get_ipython().run_line_magic('matplotlib', 'inline')
#      18 import matplotlib.pyplot as plt
# ---> 19 import seaborn as sns
#      20
#      21 from jupyterthemes import jtplot
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
jtplot.style(theme = "monokai", context = "notebook", ticks = True)

# %%
def read_text(files, print_n=1000):
    '''
        This function reads text files from a directory and creates a list of documents(corpus).
    '''
    docs = []
    for idx, f in enumerate(files):
        if idx % print_n == 0:
            print("Reading file number : {}".format(idx))
        with open(f, "r") as doc:
            text = doc.read()
        docs.append(text)
    return docs

# %%
def treebank_to_wordnet_pos_converter(treebank_pos_tag):
    '''
        This function converts tree bank POS tags into wordnet compatible POS tags.
    '''
    if treebank_pos_tag.startswith("J"):
        return wordnet.ADJ
    elif treebank_pos_tag.startswith("V"):
        return wordnet.VERB
    elif treebank_pos_tag.startswith("N"):
        return wordnet.NOUN
    elif treebank_pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def preprocess_text(corpus, print_n=1000):
    '''
        This function performs unstructured data preprocessing.
    '''
    l_stop_words = stopwords.words('english')
    lemmatizer = WordNetLemmatizer()
    count_docs = len(corpus)
    processed_corpus = []
    for idx, doc in enumerate(corpus):
        if idx % print_n == 0:
            print("Processing Document : {} in {}".format(idx, count_docs))
        # 1. Convert text to lower case
        doc = doc.lower()

        # 2. Tokenize documents
        doc_tokenized = doc.split()

        # 3. POS Tagging
        l_token_pos_tags = pos_tag(doc_tokenized)

        # 4. Remove Stop Words
        doc_token_pos = [token_pos_tuple for token_pos_tuple in l_token_pos_tags
                         if token_pos_tuple[0] not in l_stop_words]

        # 5. Remove characters other than alphabet
        doc_token_pos = [(re.sub(r'[^a-zA-Z]', '', token), pos)
                         for token, pos in doc_token_pos]
        
        doc_token_pos = [(token, pos)
                         for token, pos in doc_token_pos if token!='']
        
        # 6. Lemmatization - Convert each token into lexicon
        doc_token_pos = [(token, treebank_to_wordnet_pos_converter(pos))
                         for token, pos in doc_token_pos]

        doc_token_lemmatized = [lemmatizer.lemmatize(
            token, pos) for token, pos in doc_token_pos]
        
        processed_corpus.append(doc_token_lemmatized)

    return processed_corpus

# %%
def return_frequent_words(corpus, threshold_percentile=0.9):
    df_term_frequency = pd.DataFrame.from_dict(
        Counter(chain(*corpus)), orient="index")
    df_term_frequency.reset_index(inplace=True)
    df_term_frequency.columns = ["token", "frequency"]
    df_term_frequency = df_term_frequency.sort_values(
        by="frequency", ascending=False)
    df_term_frequency["frequency_ratio"] = df_term_frequency["frequency"] / \
        df_term_frequency["frequency"].sum()
    df_term_frequency["cum_frequency_ratio"] = df_term_frequency["frequency_ratio"].cumsum()

    df_term_frequency = df_term_frequency.loc[df_term_frequency["cum_frequency_ratio"] < threshold_percentile]
    frequent_tokens = df_term_frequency.loc[:, "token"].unique()

    df_term_frequency["idx"] = np.arange(1, df_term_frequency.shape[0]+1, 1)

    dict_token_idx_mapping = dict(
        zip(df_term_frequency["token"].values, df_term_frequency["idx"].values))
    return frequent_tokens, dict_token_idx_mapping

# %%
def prepare_data(print_n=1000):

    # 1. Read Raw Text
    pos_files = [os.path.join("data/aclImdb/train/pos", f)
                 for f in os.listdir("data/aclImdb/train/pos")]
    neg_files = [os.path.join("data/aclImdb/train/neg", f)
                 for f in os.listdir("data/aclImdb/train/neg")]

    pos_reviews = read_text(pos_files, print_n)
    neg_reviews = read_text(neg_files, print_n)

    # 2. Preprocess Text
    pos_processed = preprocess_text(pos_reviews, print_n)
    neg_processed = preprocess_text(neg_reviews, print_n)

    processed_corpus = pos_processed+neg_processed

    # 3. Find Frequent Tokens
    high_occurrence_tokens, token_idx_map = return_frequent_words(
        processed_corpus)

    df_pos = pd.DataFrame()
    df_pos["review"] = pos_processed
    df_pos["sentiment"] = 1
    df_neg = pd.DataFrame()
    df_neg["review"] = neg_processed
    df_neg["sentiment"] = 0

    # 3. Create Dataframe with reviews
    df_reviews = pd.concat([df_pos, df_neg], axis=0)
    df_reviews["review_frequent_tokens"] = df_reviews["review"].apply(
        lambda review: [token for token in review if token in high_occurrence_tokens])

    # 4. Create index number per token
    df_reviews["review_frequent_tokens_idx"] = df_reviews["review_frequent_tokens"].apply(
        lambda review: [token_idx_map[token] for token in review])

    return df_reviews, high_occurrence_tokens, token_idx_map

# %%
df_train_reviews, high_occurrence_tokens, token_idx_map = prepare_data(print_n=1000)
# Out:
# Reading file number : 0
# Reading file number : 1000
# Reading file number : 2000
# Reading file number : 3000
# Reading file number : 4000
# Reading file number : 5000
# Reading file number : 6000
# Reading file number : 7000
# Reading file number : 8000
# Reading file number : 9000
# Reading file number : 10000
# Reading file number : 11000
# Reading file number : 12000
# Reading file number : 0
# Reading file number : 1000
# Reading file number : 2000
# Reading file number : 3000
# Reading file number : 4000
# Reading file number : 5000
# Reading file number : 6000
# Reading file number : 7000
# Reading file number : 8000
# Reading file number : 9000
# Reading file number : 10000
# Reading file number : 11000
# Reading file number : 12000
# Processing Document : 0 in 12500
# Processing Document : 1000 in 12500
# Processing Document : 2000 in 12500
# Processing Document : 3000 in 12500
# Processing Document : 4000 in 12500
# Processing Document : 5000 in 12500
# Processing Document : 6000 in 12500
# Processing Document : 7000 in 12500
# Processing Document : 8000 in 12500
# Processing Document : 9000 in 12500
# Processing Document : 10000 in 12500
# Processing Document : 11000 in 12500
# Processing Document : 12000 in 12500
# Processing Document : 0 in 12500
# Processing Document : 1000 in 12500
# Processing Document : 2000 in 12500
# Processing Document : 3000 in 12500
# Processing Document : 4000 in 12500
# Processing Document : 5000 in 12500
# Processing Document : 6000 in 12500
# Processing Document : 7000 in 12500
# Processing Document : 8000 in 12500
# Processing Document : 9000 in 12500
# Processing Document : 10000 in 12500
# Processing Document : 11000 in 12500
# Processing Document : 12000 in 12500

# %%
df_train_reviews.to_pickle("data/processed_data/train_reviews_processed.pkl")

# %%
df_train_reviews.to_hdf("data/processed_data/train_reviews_processed.h5", key = "df")


with open("data/processed_data/high_occurrence_tokens.pkl", "wb") as f:
    pickle.dump(high_occurrence_tokens, f)
    
with open("data/processed_data/token_idx_map.pkl", "wb") as f:
    pickle.dump(token_idx_map, f)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['review', 'review_frequent_tokens', 'review_frequent_tokens_idx']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
with open("data/processed_data/token_idx_map.pkl", "rb") as f:
    c = pickle.load(f)

# %%
c
# Out:
# {'br': 1,
#  'movie': 2,
#  'film': 3,
#  'one': 4,
#  'make': 5,
#  'like': 6,
#  'see': 7,
#  'get': 8,
#  'good': 9,
#  'time': 10,
#  'character': 11,
#  'go': 12,
#  'watch': 13,
#  'story': 14,
#  'the': 15,
#  'even': 16,
#  'it': 17,
#  'bad': 18,
#  'would': 19,
#  'really': 20,
#  'think': 21,
#  'well': 22,
#  'show': 23,
#  'scene': 24,
#  'great': 25,
#  'much': 26,
#  'look': 27,
#  'say': 28,
#  'people': 29,
#  'also': 30,
#  'know': 31,
#  'first': 32,
#  'give': 33,
#  'take': 34,
#  'end': 35,
#  'way': 36,
#  'come': 37,
#  'play': 38,
#  'love': 39,
#  'thing': 40,
#  'find': 41,
#  'could': 42,
#  'seem': 43,
#  'life': 44,
#  'two': 45,
#  'many': 46,
#  'work': 47,
#  'plot': 48,
#  'want': 49,
#  'never': 50,
#  'little': 51,
#  'actor': 52,
#  'best': 53,
#  'year': 54,
#  'try': 55,
#  'ever': 56,
#  'still': 57,
#  'man': 58,
#  'this': 59,
#  'i': 60,
#  'part': 61,
#  'something': 62,
#  'back': 63,
#  'im': 64,
#  'use': 65,
#  'lot': 66,
#  'old': 67,
#  'director': 68,
#  'performance': 69,
#  'real': 70,
#  'funny': 71,
#  'though': 72,
#  'do': 73,
#  'woman': 74,
#  'new': 75,
#  'acting': 76,
#  'another': 77,
#  'actually': 78,
#  'nothing': 79,
#  'guy': 80,
#  'young': 81,
#  'big': 82,
#  's': 83,
#  'role': 84,
#  'star': 85,
#  'start': 86,
#  'point': 87,
#  'act': 88,
#  'feel': 89,
#  'every': 90,
#  'leave': 91,
#  'tell': 92,
#  'cast': 93,
#  'become': 94,
#  'girl': 95,
#  'cant': 96,
#  'thats': 97,
#  'there': 98,
#  'turn': 99,
#  'quite': 100,
#  'world': 101,
#  'fact': 102,
#  'and': 103,
#  'be': 104,
#  'pretty': 105,
#  'u': 106,
#  'around': 107,
#  'day': 108,
#  'minute': 109,
#  'however': 110,
#  'horror': 111,
#  'comedy': 112,
#  'long': 113,
#  'all': 114,
#  'enough': 115,
#  'may': 116,
#  'right': 117,
#  'ive': 118,
#  'original': 119,
#  'action': 120,
#  'set': 121,
#  'kill': 122,
#  'bit': 123,
#  'family': 124,
#  'need': 125,
#  'without': 126,
#  'enjoy': 127,
#  'keep': 128,
#  'fan': 129,
#  'always': 130,
#  'series': 131,
#  'saw': 132,
#  'script': 133,
#  'line': 134,
#  'a': 135,
#  'almost': 136,
#  'last': 137,
#  'put': 138,
#  'least': 139,
#  'that': 140,
#  'must': 141,
#  'whole': 142,
#  'happen': 143,
#  'write': 144,
#  'believe': 145,
#  'kid': 146,
#  'music': 147,
#  'mean': 148,
#  'kind': 149,
#  'friend': 150,
#  'anything': 151,
#  'might': 152,
#  'place': 153,
#  'far': 154,
#  'since': 155,
#  'lead': 156,
#  'probably': 157,
#  'reason': 158,
#  'book': 159,
#  'me': 160,
#  'rather': 161,
#  'help': 162,
#  'yet': 163,
#  'effect': 164,
#  'away': 165,
#  'name': 166,
#  'sure': 167,
#  'moment': 168,
#  'tv': 169,
#  'live': 170,
#  'run': 171,
#  'laugh': 172,
#  'read': 173,
#  'fun': 174,
#  'idea': 175,
#  'let': 176,
#  'anyone': 177,
#  'in': 178,
#  'call': 179,
#  'audience': 180,
#  'although': 181,
#  'hard': 182,
#  'course': 183,
#  'episode': 184,
#  'especially': 185,
#  'child': 186,
#  'interesting': 187,
#  'he': 188,
#  'expect': 189,
#  'job': 190,
#  'bring': 191,
#  'different': 192,
#  'version': 193,
#  'american': 194,
#  'here': 195,
#  'screen': 196,
#  'maybe': 197,
#  'someone': 198,
#  'dvd': 199,
#  'sense': 200,
#  'money': 201,
#  'main': 202,
#  'worth': 203,
#  'high': 204,
#  'true': 205,
#  'everything': 206,
#  'problem': 207,
#  'them': 208,
#  'second': 209,
#  'three': 210,
#  'night': 211,
#  'john': 212,
#  'him': 213,
#  'war': 214,
#  'house': 215,
#  'sound': 216,
#  'together': 217,
#  'instead': 218,
#  'beautiful': 219,
#  'shot': 220,
#  'fall': 221,
#  'begin': 222,
#  'wife': 223,
#  'everyone': 224,
#  'move': 225,
#  'special': 226,
#  'waste': 227,
#  'face': 228,
#  'excellent': 229,
#  'mind': 230,
#  'hour': 231,
#  'talk': 232,
#  'lose': 233,
#  'father': 234,
#  'recommend': 235,
#  'death': 236,
#  'but': 237,
#  'black': 238,
#  'remember': 239,
#  'classic': 240,
#  'nice': 241,
#  'again': 242,
#  'simply': 243,
#  'viewer': 244,
#  'short': 245,
#  'boy': 246,
#  'you': 247,
#  'out': 248,
#  'include': 249,
#  'follow': 250,
#  'piece': 251,
#  'change': 252,
#  'on': 253,
#  'early': 254,
#  'appear': 255,
#  'poor': 256,
#  'attempt': 257,
#  'miss': 258,
#  'understand': 259,
#  'completely': 260,
#  'picture': 261,
#  'suppose': 262,
#  'head': 263,
#  'else': 264,
#  'couple': 265,
#  'production': 266,
#  'eye': 267,
#  'home': 268,
#  'rest': 269,
#  'less': 270,
#  'fight': 271,
#  'later': 272,
#  'men': 273,
#  'so': 274,
#  'human': 275,
#  'hand': 276,
#  'song': 277,
#  'feature': 278,
#  'care': 279,
#  'hollywood': 280,
#  'hear': 281,
#  'either': 282,
#  'truly': 283,
#  'interest': 284,
#  'wrong': 285,
#  'along': 286,
#  'half': 287,
#  'lack': 288,
#  'dead': 289,
#  'release': 290,
#  'small': 291,
#  'word': 292,
#  'title': 293,
#  'camera': 294,
#  'direct': 295,
#  'video': 296,
#  'meet': 297,
#  'next': 298,
#  'stupid': 299,
#  'add': 300,
#  'perhaps': 301,
#  'save': 302,
#  'sort': 303,
#  'full': 304,
#  'hope': 305,
#  'decide': 306,
#  'case': 307,
#  'wonderful': 308,
#  'late': 309,
#  'view': 310,
#  'person': 311,
#  'others': 312,
#  'theres': 313,
#  'killer': 314,
#  'review': 315,
#  'awful': 316,
#  'her': 317,
#  'dialogue': 318,
#  'wonder': 319,
#  'murder': 320,
#  'school': 321,
#  'involve': 322,
#  'not': 323,
#  'create': 324,
#  'terrible': 325,
#  'die': 326,
#  'sex': 327,
#  'top': 328,
#  'definitely': 329,
#  'mr': 330,
#  'perfect': 331,
#  'often': 332,
#  'comment': 333,
#  'consider': 334,
#  'sequence': 335,
#  'brother': 336,
#  'shoot': 337,
#  'low': 338,
#  'style': 339,
#  'fine': 340,
#  'game': 341,
#  'joke': 342,
#  'base': 343,
#  'finally': 344,
#  'felt': 345,
#  'budget': 346,
#  'example': 347,
#  'guess': 348,
#  'flick': 349,
#  'who': 350,
#  'mother': 351,
#  'absolutely': 352,
#  'yes': 353,
#  'entire': 354,
#  'sit': 355,
#  'actress': 356,
#  'certainly': 357,
#  'surprise': 358,
#  'cinema': 359,
#  'up': 360,
#  'age': 361,
#  'mention': 362,
#  'art': 363,
#  'is': 364,
#  'ask': 365,
#  'writer': 366,
#  'car': 367,
#  'if': 368,
#  'evil': 369,
#  'white': 370,
#  'several': 371,
#  'overall': 372,
#  'quality': 373,
#  'stand': 374,
#  'direction': 375,
#  'id': 376,
#  'too': 377,
#  'now': 378,
#  'drama': 379,
#  'buy': 380,
#  'stop': 381,
#  'close': 382,
#  'son': 383,
#  'dark': 384,
#  'favorite': 385,
#  'hold': 386,
#  'already': 387,
#  'experience': 388,
#  'despite': 389,
#  'oh': 390,
#  'force': 391,
#  'side': 392,
#  'wait': 393,
#  'cut': 394,
#  'hit': 395,
#  'unfortunately': 396,
#  'throughout': 397,
#  'number': 398,
#  'final': 399,
#  'boring': 400,
#  'matter': 401,
#  'voice': 402,
#  'michael': 403,
#  'totally': 404,
#  'learn': 405,
#  'deal': 406,
#  'relationship': 407,
#  'humor': 408,
#  'heart': 409,
#  'wish': 410,
#  'type': 411,
#  'history': 412,
#  'support': 413,
#  'past': 414,
#  'able': 415,
#  'walk': 416,
#  'theyre': 417,
#  'strong': 418,
#  'behind': 419,
#  'hero': 420,
#  'town': 421,
#  'stay': 422,
#  'genre': 423,
#  'spend': 424,
#  'realize': 425,
#  'present': 426,
#  'open': 427,
#  'credit': 428,
#  'daughter': 429,
#  'city': 430,
#  'fail': 431,
#  'theme': 432,
#  'break': 433,
#  'pay': 434,
#  'power': 435,
#  'light': 436,
#  'event': 437,
#  'portray': 438,
#  'sometimes': 439,
#  'rent': 440,
#  'feeling': 441,
#  'manage': 442,
#  'zombie': 443,
#  'chance': 444,
#  'horrible': 445,
#  'question': 446,
#  'soon': 447,
#  'what': 448,
#  'obviously': 449,
#  'score': 450,
#  'throw': 451,
#  'stuff': 452,
#  'with': 453,
#  'ill': 454,
#  'brilliant': 455,
#  'forget': 456,
#  'return': 457,
#  'blood': 458,
#  'talent': 459,
#  'figure': 460,
#  'decent': 461,
#  'body': 462,
#  'highly': 463,
#  'order': 464,
#  'for': 465,
#  'element': 466,
#  'group': 467,
#  'musical': 468,
#  'except': 469,
#  'god': 470,
#  'level': 471,
#  'complete': 472,
#  'cannot': 473,
#  'slow': 474,
#  'hell': 475,
#  'to': 476,
#  'deserve': 477,
#  'please': 478,
#  'police': 479,
#  'catch': 480,
#  'today': 481,
#  'situation': 482,
#  'lady': 483,
#  'dance': 484,
#  'twist': 485,
#  'novel': 486,
#  'extremely': 487,
#  'dream': 488,
#  'particularly': 489,
#  'career': 490,
#  'beginning': 491,
#  'no': 492,
#  'obvious': 493,
#  'robert': 494,
#  'pick': 495,
#  'violence': 496,
#  'cause': 497,
#  'simple': 498,
#  'husband': 499,
#  'etc': 500,
#  'scary': 501,
#  'then': 502,
#  'documentary': 503,
#  'anyway': 504,
#  'country': 505,
#  'theater': 506,
#  'touch': 507,
#  'itbr': 508,
#  'speak': 509,
#  'grow': 510,
#  'alone': 511,
#  'opinion': 512,
#  'none': 513,
#  'sad': 514,
#  'exactly': 515,
#  'reality': 516,
#  'result': 517,
#  'david': 518,
#  'effort': 519,
#  'ok': 520,
#  'allow': 521,
#  'ago': 522,
#  'hes': 523,
#  'female': 524,
#  'whose': 525,
#  'king': 526,
#  'state': 527,
#  'usually': 528,
#  'room': 529,
#  'season': 530,
#  'which': 531,
#  'sequel': 532,
#  'rock': 533,
#  'serious': 534,
#  'compare': 535,
#  'across': 536,
#  'cinematography': 537,
#  'cool': 538,
#  'check': 539,
#  'james': 540,
#  'value': 541,
#  'somewhat': 542,
#  'filmmaker': 543,
#  'provide': 544,
#  'gore': 545,
#  'entertaining': 546,
#  'usual': 547,
#  'strange': 548,
#  'amazing': 549,
#  'possible': 550,
#  'bore': 551,
#  'sister': 552,
#  'rating': 553,
#  'offer': 554,
#  'comic': 555,
#  'off': 556,
#  'huge': 557,
#  'major': 558,
#  'message': 559,
#  'seriously': 560,
#  'crap': 561,
#  'local': 562,
#  'mostly': 563,
#  'explain': 564,
#  'focus': 565,
#  'ridiculous': 566,
#  'english': 567,
#  'hilarious': 568,
#  'more': 569,
#  'happy': 570,
#  'due': 571,
#  'tale': 572,
#  'single': 573,
#  'drive': 574,
#  'form': 575,
#  'apparently': 576,
#  'avoid': 577,
#  'street': 578,
#  'pull': 579,
#  'easy': 580,
#  'basically': 581,
#  'note': 582,
#  'important': 583,
#  'clearly': 584,
#  'thriller': 585,
#  'jack': 586,
#  'cheap': 587,
#  'attention': 588,
#  'cop': 589,
#  'george': 590,
#  'better': 591,
#  'win': 592,
#  'british': 593,
#  'easily': 594,
#  'stick': 595,
#  'weak': 596,
#  'silly': 597,
#  'dialog': 598,
#  'prove': 599,
#  'subject': 600,
#  'team': 601,
#  'mystery': 602,
#  'of': 603,
#  'cover': 604,
#  'oscar': 605,
#  'moviebr': 606,
#  'monster': 607,
#  'whats': 608,
#  'television': 609,
#  'paul': 610,
#  'modern': 611,
#  'future': 612,
#  'beyond': 613,
#  'class': 614,
#  'whether': 615,
#  'four': 616,
#  'deliver': 617,
#  'five': 618,
#  'doubt': 619,
#  'earth': 620,
#  'peter': 621,
#  'dog': 622,
#  'romantic': 623,
#  'similar': 624,
#  'animation': 625,
#  'member': 626,
#  'or': 627,
#  'why': 628,
#  'fill': 629,
#  'imagine': 630,
#  'parent': 631,
#  'entertainment': 632,
#  'upon': 633,
#  'richard': 634,
#  'predictable': 635,
#  'producer': 636,
#  'draw': 637,
#  'villain': 638,
#  'storyline': 639,
#  'aspect': 640,
#  'remind': 641,
#  'image': 642,
#  'within': 643,
#  'near': 644,
#  'crime': 645,
#  'produce': 646,
#  'bunch': 647,
#  'nearly': 648,
#  'escape': 649,
#  'adult': 650,
#  'ten': 651,
#  'enjoyable': 652,
#  'carry': 653,
#  'filmbr': 654,
#  'clear': 655,
#  'middle': 656,
#  'capture': 657,
#  'dull': 658,
#  'actual': 659,
#  'gun': 660,
#  'steal': 661,
#  'york': 662,
#  'mark': 663,
#  'before': 664,
#  'remain': 665,
#  'among': 666,
#  'plan': 667,
#  'deep': 668,
#  'typical': 669,
#  'entertain': 670,
#  'fantastic': 671,
#  'battle': 672,
#  'writing': 673,
#  'detail': 674,
#  'attack': 675,
#  'fire': 676,
#  'chase': 677,
#  'hate': 678,
#  'send': 679,
#  'certain': 680,
#  'remake': 681,
#  'general': 682,
#  'red': 683,
#  'wear': 684,
#  'match': 685,
#  'straight': 686,
#  'fit': 687,
#  'about': 688,
#  'material': 689,
#  'french': 690,
#  'soundtrack': 691,
#  'sorry': 692,
#  'famous': 693,
#  'develop': 694,
#  'de': 695,
#  'somehow': 696,
#  'other': 697,
#  'tom': 698,
#  'period': 699,
#  'opening': 700,
#  'fast': 701,
#  'lee': 702,
#  'victim': 703,
#  'agree': 704,
#  'mess': 705,
#  'spoiler': 706,
#  'space': 707,
#  'air': 708,
#  'standard': 709,
#  'soldier': 710,
#  'discover': 711,
#  'premise': 712,
#  'stage': 713,
#  'baby': 714,
#  'particular': 715,
#  'lame': 716,
#  'emotion': 717,
#  'cry': 718,
#  'bill': 719,
#  'admit': 720,
#  'third': 721,
#  'romance': 722,
#  'shock': 723,
#  'finish': 724,
#  'realistic': 725,
#  'build': 726,
#  'choose': 727,
#  'continue': 728,
#  'cartoon': 729,
#  'copy': 730,
#  'atmosphere': 731,
#  'annoy': 732,
#  'eventually': 733,
#  'th': 734,
#  'truth': 735,
#  'describe': 736,
#  'screenplay': 737,
#  'possibly': 738,
#  'pass': 739,
#  'large': 740,
#  'treat': 741,
#  'indeed': 742,
#  'background': 743,
#  'nature': 744,
#  'ending': 745,
#  'japanese': 746,
#  'student': 747,
#  'difficult': 748,
#  'disney': 749,
#  'western': 750,
#  'poorly': 751,
#  'issue': 752,
#  'sexual': 753,
#  'male': 754,
#  'whatever': 755,
#  'thought': 756,
#  'struggle': 757,
#  'secret': 758,
#  'average': 759,
#  'list': 760,
#  'fear': 761,
#  'my': 762,
#  'suspense': 763,
#  'animal': 764,
#  'contain': 765,
#  'okay': 766,
#  'appreciate': 767,
#  'marry': 768,
#  'pace': 769,
#  'believable': 770,
#  'charm': 771,
#  'date': 772,
#  'drug': 773,
#  'hot': 774,
#  'choice': 775,
#  'crazy': 776,
#  'fly': 777,
#  'dr': 778,
#  'b': 779,
#  'weird': 780,
#  'beauty': 781,
#  'america': 782,
#  'accent': 783,
#  'society': 784,
#  'spirit': 785,
#  'joe': 786,
#  'notice': 787,
#  'free': 788,
#  'doctor': 789,
#  'bear': 790,
#  'emotional': 791,
#  'otherwise': 792,
#  'fantasy': 793,
#  'memorable': 794,
#  'studio': 795,
#  'mistake': 796,
#  'development': 797,
#  'unless': 798,
#  'down': 799,
#  'shame': 800,
#  'hat': 801,
#  'superb': 802,
#  'award': 803,
#  'masterpiece': 804,
#  'footage': 805,
#  'appeal': 806,
#  'box': 807,
#  'creepy': 808,
#  'adventure': 809,
#  'dramatic': 810,
#  'sing': 811,
#  'project': 812,
#  'total': 813,
#  'cheesy': 814,
#  'dumb': 815,
#  'towards': 816,
#  'badly': 817,
#  'at': 818,
#  'forward': 819,
#  'water': 820,
#  'previous': 821,
#  'bother': 822,
#  'plus': 823,
#  'as': 824,
#  'ghost': 825,
#  'hop': 826,
#  'rat': 827,
#  'personal': 828,
#  'plenty': 829,
#  'convince': 830,
#  'incredibly': 831,
#  'trouble': 832,
#  'costume': 833,
#  'quickly': 834,
#  'dont': 835,
#  'perfectly': 836,
#  'la': 837,
#  'suggest': 838,
#  'unique': 839,
#  'jump': 840,
#  'suck': 841,
#  'control': 842,
#  'party': 843,
#  'hardly': 844,
#  'vampire': 845,
#  'have': 846,
#  'beat': 847,
#  'girlfriend': 848,
#  'gay': 849,
#  'interested': 850,
#  'rich': 851,
#  'imdb': 852,
#  'apart': 853,
#  'cat': 854,
#  'christmas': 855,
#  'various': 856,
#  'business': 857,
#  'lover': 858,
#  'week': 859,
#  'potential': 860,
#  'reveal': 861,
#  'rate': 862,
#  'design': 863,
#  'color': 864,
#  'wood': 865,
#  'living': 866,
#  'band': 867,
#  'inside': 868,
#  'ben': 869,
#  'scifi': 870,
#  'term': 871,
#  'amount': 872,
#  'films': 873,
#  'powerful': 874,
#  'front': 875,
#  'outside': 876,
#  'fairly': 877,
#  'scream': 878,
#  'answer': 879,
#  'jane': 880,
#  'lie': 881,
#  'political': 882,
#  'eat': 883,
#  'success': 884,
#  'blow': 885,
#  'unlike': 886,
#  'plain': 887,
#  'respect': 888,
#  'himself': 889,
#  'german': 890,
#  'william': 891,
#  'us': 892,
#  'company': 893,
#  'recently': 894,
#  'odd': 895,
#  'while': 896,
#  'claim': 897,
#  'crew': 898,
#  'nudity': 899,
#  'appearance': 900,
#  'portrayal': 901,
#  'pure': 902,
#  'sadly': 903,
#  'share': 904,
#  'sweet': 905,
#  'cute': 906,
#  'talented': 907,
#  'tone': 908,
#  'concept': 909,
#  'flat': 910,
#  'setting': 911,
#  'track': 912,
#  'store': 913,
#  'incredible': 914,
#  'dress': 915,
#  'location': 916,
#  'tension': 917,
#  'roll': 918,
#  'master': 919,
#  'public': 920,
#  'flaw': 921,
#  'scott': 922,
#  'island': 923,
#  'social': 924,
#  'rise': 925,
#  'serve': 926,
#  'ability': 927,
#  'office': 928,
#  'player': 929,
#  'basic': 930,
#  'memory': 931,
#  'era': 932,
#  'reach': 933,
#  'popular': 934,
#  'amaze': 935,
#  'ruin': 936,
#  'edit': 937,
#  'train': 938,
#  'positive': 939,
#  'mary': 940,
#  'slightly': 941,
#  'suffer': 942,
#  'suddenly': 943,
#  'depth': 944,
#  'neither': 945,
#  'listen': 946,
#  'clever': 947,
#  'entirely': 948,
#  'step': 949,
#  'alien': 950,
#  'familiar': 951,
#  'intelligent': 952,
#  'language': 953,
#  'adaptation': 954,
#  'channel': 955,
#  'ultimately': 956,
#  'accept': 957,
#  'century': 958,
#  'visual': 959,
#  'exist': 960,
#  'sell': 961,
#  'approach': 962,
#  'italian': 963,
#  'tear': 964,
#  'brain': 965,
#  'sleep': 966,
#  'trip': 967,
#  'ring': 968,
#  'land': 969,
#  'kick': 970,
#  'disappointed': 971,
#  'planet': 972,
#  'revenge': 973,
#  'spot': 974,
#  'recent': 975,
#  'successful': 976,
#  'door': 977,
#  'creature': 978,
#  'cold': 979,
#  'destroy': 980,
#  'taste': 981,
#  'science': 982,
#  'camp': 983,
#  'violent': 984,
#  'search': 985,
#  'computer': 986,
#  'slasher': 987,
#  'million': 988,
#  'former': 989,
#  'trash': 990,
#  'drag': 991,
#  'culture': 992,
#  'over': 993,
#  'indian': 994,
#  'mix': 995,
#  'own': 996,
#  'maker': 997,
#  'receive': 998,
#  'solid': 999,
#  'soul': 1000,
#  ...}

# %%
test= pd.read_hdf("data/processed_data/train_reviews_processed.h5")
test.head()
# Out:
#                                               review  sentiment  \
# 0  [movie, get, respect, sure, lot, memorable, qu...          1
# 1  [bizarre, horror, movie, fill, famous, face, s...          1
# 2  [solid, unremarkable, film, matthau, einstein,...          1
# 3  [strange, feeling, sit, alone, theater, occupy...          1
# 4  [probably, already, know, now, additional, epi...          1
#
#                               review_frequent_tokens  \
# 0  [movie, get, respect, sure, lot, memorable, qu...
# 1  [bizarre, horror, movie, fill, famous, face, s...
# 2  [solid, film, wonderful, favorite, part, thing...
# 3  [strange, feeling, sit, alone, theater, parent...
# 4  [probably, already, know, now, episode, never,...
#
#                           review_frequent_tokens_idx
# 0  [2, 8, 888, 167, 66, 794, 1646, 760, 1201, 630...
# 1  [1006, 111, 2, 629, 693, 228, 661, 272, 169, 1...
# 2  [999, 3, 308, 385, 61, 40, 19, 5, 12, 36, 7, 2...
# 3  [548, 441, 355, 511, 506, 631, 146, 345, 6, 21...
# 4  [157, 387, 31, 378, 184, 50, 708, 310, 118, 13...
